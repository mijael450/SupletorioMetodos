2, 31.56), (-0.16, 27.0), (-0.12, 31.62), (-0.08, 35.5), (-0.04, 32.82), (-0.0, 28.65), (0.03, 36.6), (0.07, 33.92), (0.11, 35.97), (0.15, 30.86), (0.19, 31.47), (0.23, 38.52), (0.27, 32.5), (0.31, 36.67), (0.35, 31.59), (0.39, 43.82), (0.43, 37.48), (0.47, 34.57), (0.51, 33.19), (0.55, 37.98), (0.59, 42.94), (0.63, 37.8), (0.67, 43.53), (0.71, 34.77), (0.75, 33.96), (0.79, 34.17), (0.83, 40.71), (0.87, 40.09), (0.91, 45.15), (0.95, 46.26), (1.0, 40.69)] 
x1= [x for x, y in x1y1]
y1= [y for x, y in x1y1]
print(x1)
print(y1)
print(len(x1))
print(len(y1))

#Derivadas parcales para la funcion cuadratica
def der_parcial_0x2(xs: list, ys: list) -> tuple[float, float, float,float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto al parámetro 0 al reemplazar los valores ``xs`` y ``ys``. La ecuación es de la forma:
    c_2 * a_2 ac_1 * a_1 + c_0 * a_0 = c_ind
    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return
    
    ``c_2``: coeficiente del parámetro 2.

    ``c_1``: coeficiente del parámetro 1.

    ``c_0``: coeficiente del parámetro 0.

    ``c_ind``: coeficiente del término independiente.

    """
    c_2 = 0
    c_1 = 0
    c_0 = 0
    c_ind = 0

    # coeficiente del término independiente
    c_ind = sum(ys)

    # coeficiente del parámetro 2
    c_2 = sum([x**2 for x in xs])

    # coeficiente del parámetro 1
    c_1 = sum(xs)

    # coeficiente del parámetro 0
    c_0 = len(xs)
    
    return (c_2, c_1, c_0, c_ind)

def der_parcial_1x2(xs: list, ys: list) -> tuple[float, float, float,float]:  
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto al parámetro 1 al reemplazar los valores ``xs`` y ``ys``. La ecuación es de la forma:
    c_2 * a_2 ac_1 * a_1 + c_0 * a_0 = c_ind
    ## Parameters
    ``xs``: lista de valores de x.
    ``ys``: lista de valores de y.
    ## Return
    ``c_2``: coeficiente del parámetro 2.
    ``c_1``: coeficiente del parámetro 1.
    ``c_0``: coeficiente del parámetro 0.
    ``c_ind``: coeficiente del término independiente.
    """
    c_2 = 0
    c_1 = 0
    c_0 = 0
    c_ind = 0
    # coeficiente del término independiente
    c_ind = sum([x*y for x,y in zip(xs,ys)])
    # coeficiente del parámetro 2
    c_2 = sum([x**3 for x in xs])
    # coeficiente del parámetro 1
    c_1 = sum([x**2 for x in xs])
    # coeficiente del parámetro 0
    c_0 = sum(xs)
    return (c_2, c_1, c_0, c_ind) 

def der_parcial_2x2(xs: list, ys: list) -> tuple[float, float, float,float]:  
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto al parámetro 1 al reemplazar los valores ``xs`` y ``ys``. La ecuación es de la forma:
    c_2 * a_2 ac_1 * a_1 + c_0 * a_0 = c_ind
    ## Parameters
    ``xs``: lista de valores de x.
    ``ys``: lista de valores de y.
    ## Return
    ``c_2``: coeficiente del parámetro 2.
    ``c_1``: coeficiente del parámetro 1.
    ``c_0``: coeficiente del parámetro 0.
    ``c_ind``: coeficiente del término independiente.
    """
    c_2 = 0
    c_1 = 0
    c_0 = 0
    c_ind = 0
    # coeficiente del término independiente
    c_ind = sum([x**2*y for x,y in zip(xs,ys)])
    # coeficiente del parámetro 2
    c_2 = sum([x**4 for x in xs])
    # coeficiente del parámetro 1
    c_1 = sum([x**3 for x in xs])
    # coeficiente del parámetro 0
    c_0 = sum([x**2 for x in xs])
    return (c_2, c_1, c_0, c_ind)
# UTILICE:
a0,a1,a2=min_cuadrados.ajustar_min_cuadrados(x1,y1,gradiente=[der_parcial_0x2,der_parcial_1x2,der_parcial_2x2])

def f(x):
    return a2+a1*x+a0*x**2
#Grafica interpolacion cuadratica

xcuadratica = np.linspace(min(x1),max(x1),100)
ycuadratica = [f(x) for x in xcuadratica]
plt.plot(xcuadratica,ycuadratica)
plt.scatter(x1,y1)
plt.xlabel("x")

#Error  relativo 
e=[]
for x,y in zip(x1,y1):
    e.append(abs((y-f(x)/y)))
print("Error",e)
#Minimo error relativo 
print("Minimo error",min(e))
#Maximo error relativo
print("Maximo error",max(e))
#Promedio error relativo
print("Promedio error",sum(e)/len(e))
# Out:
# [02-20 13:29:46][INFO] 2025-02-20 13:29:46.862313
# [02-20 13:29:46][INFO] victor| 2025-02-20 13:29:46.867302
# [02-20 13:29:46][INFO] 2025-02-20 13:29:46.876279
# [02-20 13:29:46][INFO] victor| 2025-02-20 13:29:46.883259
# ...

# %% [markdown]
# ## Explicacion
# * Se opto por realizar la interpolacion mediante la funcion cuadratica ya que la grafica de puntos describe el extremo derecho de una parabola
# * funcion a interpolar y=a2x**2+a1x+a0
